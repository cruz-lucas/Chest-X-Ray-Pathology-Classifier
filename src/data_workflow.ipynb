# %%
from chexpert import CheXpertDataset

# %%
ds = CheXpertDataset(config_path='config.YAML')

# %%
ds.create_local_database('u-ignore')
# Out:
#   0%|          | 19/223414 [00:28<91:27:36,  1.47s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds.create_local_database('u-ignore')
#
# File ~/Documents/GitHub/Chest-X-Ray-Pathology-Classifier/src/chexpert.py:150, in CheXpertDataset.create_local_database(self, parquet_file_path)
#     144 def create_local_database(self, parquet_file_path: str) -> None:
#     145     """Create a local parquet file from the dataset.
#     146
#     147     Args:
#     148         parquet_file_path (str): Path to the parquet file to save the dataset.
#     149     """
# --> 150     for i, batch in enumerate(tqdm(self, total=self.__len__())):
#     151         df_pixels = pd.DataFrame({
#     152                 'pixel_values': batch['pixel_values'].numpy().flatten(),
#     153         })
#     155         df_labels = pd.DataFrame({
# ...
